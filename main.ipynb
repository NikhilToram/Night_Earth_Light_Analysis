# %% [markdown]
# # Nighttime Earth Light Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import glob
from geopy.geocoders import Nominatim
import csv
from geographiclib.geodesic import Geodesic
import multiprocessing as mp
import scatter_plot
from multiprocessing import pool
import geographiclib
# import plotly.express as px
import main
import ipywidgets as widgets
from IPython.display import display
from PIL import Image
import os
from osgeo import gdal

# %% [markdown]
# ## Socio-Economic Correlation Visualization
#
#
# #### In this section we will see the various kinds of distributions and mapping them against the economic data.

# %% [markdown]
# ##### In this analysis we use the "summation_analysis" function to map the annual total nightime.
# The same function will be used again in the other sections with different parameters.
#
# Observe the close correlation between GDP Per capita and the Night light intensity for both of the countries.
#
# What could be some of the applications of the infereneces?

# %%
main.summation_analysis('annual','germany', extrapolate_economic_data=True)
main.summation_analysis('annual','india', extrapolate_economic_data=True)

# %% [markdown]
# ##### In this analysis we use the same "summation_analysis" function to map the Monthly total nightime.
# The same function has been used again in this section with different parameters.
# notice the difference in patterns as the year goes on!
#
# Does this make sense?
#
# Think about the weather patterns in these countries!

# %%
main.summation_analysis('monthly','germany')
main.summation_analysis('monthly','india')
# Out:
# ./output/monthly/2021/*germany_masked.tif
# ./output/monthly/2022/*germany_masked.tif
# ./output/monthly/2021/*india_masked.tif
# ./output/monthly/2022/*india_masked.tif

# %% [markdown]
# ### Light Distribution
# #### This section shows us histogram distribution of the night light intensity along the decade for Germany and India
# ##### We see the diversity in the disribution increases as the years pass by. and the median night emmision increases
#
# What are the consequences of this?
#
# The reflection on the trends of energy consumption?
#
# Are we ignoring the impact on light pollution?

# %%
main.distribution_curve('annual','india')
# Out:
# ''

# %%
main.distribution_curve('annual','germany')
# Out:
# ''

# %% [markdown]
# ### Trends of economic quantiles
# #### Here we see the night light trends in the top and bottom quantiles for the countries, the cutoff being 99.5%
# ##### Notice the variation in between these quantiles and the overall trends for these countries
# What could be the inferences when the light from most brightest regions of the country dim or stagnate

# %%
main.summation_analysis('annual','germany',direction= 'top',cutoff = 0.995)
main.summation_analysis('annual','india',direction= 'top', cutoff = 0.995)

# %%
main.summation_analysis('annual','germany',direction= 'bottom',cutoff = 0.995)
main.summation_analysis('annual','india',direction= 'bottom', cutoff = 0.995)

# %% [markdown]
# ### Examine the top brightest locations
# ##### Continuing on the previous section lets find the addersses of the brightest locations and see if we find any trends on interesting points!

# %%
main.Location_analysis('annual', 'germany')
# Out:
# 'processing file 2021'
# processing file 2012
# Minimum brightness and Location
#         Unnamed: 0   Latitude  Longitude  Raster Value
# 709186      709186  54.520833   8.862502       0.13658
# Maximum brightness and Location
#        Unnamed: 0   Latitude  Longitude  Raster Value
# 75168       75168  51.483333   6.716668      1078.283
#
#
# Address: Werkstraße 1, ThyssenKrupp Steel Europe AG, Beeckerwerth, Meiderich/Beeck, Duisburg, Nordrhein-Westfalen, 47139, Deutschland,
#  Brightness: 1078.283
#
#
# __________________________________________________________________________________________________
#
#
# Address: Brammenplatzweg, Brammenplatz, Beeckerwerth, Meiderich/Beeck, Duisburg, Nordrhein-Westfalen, 47139, Deutschland,
#  Brightness: 1063.7927
#
#
# __________________________________________________________________________________________________
#
#
# ...

# %%
main.Location_analysis('annual', 'india')
# Out:
# 'processing file 2021'
# processing file 2012
# Minimum brightness and Location
#          Unnamed: 0  Latitude  Longitude  Raster Value
# 2806912     2806912   19.9625  80.920835      0.000115
# Maximum brightness and Location
#          Unnamed: 0   Latitude  Longitude  Raster Value
# 1632406     1632406  27.604166  95.404169      2631.835
#
#
# Address: Doom Dooma, Tinsukia District, Assam, India,
#  Brightness: 2631.835
#
#
# __________________________________________________________________________________________________
#
#
# Address: Doom Dooma, Tinsukia District, Assam, India,
#  Brightness: 2116.1213
#
#
# __________________________________________________________________________________________________
#
#
# Address: Doom Dooma, Tinsukia District, Assam, India,
#  Brightness: 1635.1112
#
#
# __________________________________________________________________________________________________
#
#
# processing file 2013
# Minimum brightness and Location
# ...

# %% [markdown]
# ### City-wise analysis
# #### we see the night light trends for areas in a 55km (around 34 miles) span around a city's latitude and longitude
# ##### notice and oddities or differences in the patterns of the night light trends

# %%
main.city_isolation('annual', 'germany', print_national_stat=True)
# Out:
# Input the population cutoff of the city you want to time visualize: 1000000
# Type "N" to skip visualization by individual city, Y for otherwise: N
# Berlin
# Hamburg
# Munich
# Cologne

# %%
main.city_isolation('annual', 'india', print_national_stat=True)
# Out:
# Input the population cutoff of the city you want to time visualize: 9000000
# Type "N" to skip visualization by individual city, Y for otherwise: N
# Delhi
# Mumbai
# Kolkata
# Bangalore
# Chennai
# Hyderabad
